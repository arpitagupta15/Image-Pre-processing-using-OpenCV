# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Color Filtering

# %%
img = cv2.imread('zebra.jpg')
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV) 
      
# Threshold of blue in HSV space 
lower_white = np.array([0, 0, 230])
upper_white = np.array([180, 25, 255])

  
mask = cv2.inRange(hsv, lower_white, upper_white) 
result = cv2.bitwise_and(img, img,mask = mask) 

plt.imshow(result) 

#https://www.tydac.ch/color/

# %% [markdown]
# ## contour creation

# %%
image = cv2.imread('zebra.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
edge = cv2.Canny(gray, 50, 400) 

contours, hierarchy = cv2.findContours(edge, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)  
print("Number of Contours found = " + str(len(contours))) 

contour = cv2.drawContours(image, contours, -1, (0, 255, 0), 1) 

plt.figure(figsize=(20,10))
plt.subplot(121),plt.imshow(edge),plt.title('Output1')
plt.subplot(122),plt.imshow(contour),plt.title('Output2')
plt.show()
# Out:
# Number of Contours found = 80

# %% [markdown]
# ## drawing of geometrical shapes

# %%
img1 = cv2.imread('zebra.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
start_point = (150, 100) 
end_point = (250, 200) 
color = (16, 180, 25) #any value can be given according to requirement
thickness = 5
image_line = cv2.line(img1, start_point, end_point, color, thickness) 
plt.imshow(image_line)

# %%
image = cv2.imread('zebra.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
start_point = (30, 25) 
end_point = (100, 100) 
color = (16, 34, 250) #any value can be given according to requirement
thickness = 5
image_arrow = cv2.arrowedLine(image, start_point, end_point, color, thickness, tipLength = 0.5) 
plt.imshow(image_arrow)

# %%
image = cv2.imread('zebra.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
center_coordinates = (100,75) 
axesLength = (40, 60) 
angle = 70
startAngle = 0
endAngle = 360
color = (120, 120, 255) 
thickness = 2  
#thickness = -2   # negative thickness will create color filled ellipse
image_ellipse = cv2.ellipse(image, center_coordinates, axesLength, angle, startAngle, endAngle, color, thickness)
plt.imshow(image_ellipse)

# %%
image = cv2.imread('zebra.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
center_coordinates = (120, 50) 
radius = 50
color = (255, 0, 0) 
thickness = 2
image_circle = cv2.circle(image, center_coordinates, radius, color, thickness) 
plt.imshow(image_circle)

# %%
image = cv2.imread('zebra.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
start_point = (75, 10) 
end_point = (275, 200) 
color = (100, 100, 40) 
thickness = 2
image_rect = cv2.rectangle(image, start_point, end_point, color, thickness) 
plt.imshow(image_rect)
